# %%
import numpy as np
import pandas as pd

# %%
skills = pd.read_csv('skills.csv')
cgpa = pd.read_csv('cgpa.csv')

# %%
skills.describe()
# Out:
#               S.No  COLLEGE ROLL NUMBER  UNIVERSITY REGISTRATION NUMBER  \
# count   281.000000         2.810000e+02                    2.820000e+02
# mean    148.854093         2.015011e+08                    2.116151e+11
# std     159.879542         8.572916e+01                    8.523270e+01
# min       1.000000         2.015010e+08                    2.116151e+11
# 25%      71.000000         2.015011e+08                    2.116151e+11
# 50%     141.000000         2.015012e+08                    2.116151e+11
# 75%     211.000000         2.015012e+08                    2.116151e+11
# max    2451.000000         2.015013e+08                    2.116151e+11
#
#        Unnamed: 4      SSLC %       HSC %  DIPLOMA PERCENTAGE  \
# count         0.0  282.000000  282.000000                 0.0
# mean          NaN   90.997057   85.866915                 NaN
# std           NaN    7.644195    8.878230                 NaN
# min           NaN   58.000000   54.670000                 NaN
# ...

# %%
cgpa.describe()
# Out:
#           Sl. No.      Roll No.      Reg. No.        Fail        CGPA
# count  397.000000  3.970000e+02  3.970000e+02  397.000000  397.000000
# mean   199.000000  2.015017e+08  2.111354e+11    2.108312    7.095970
# std    114.748275  8.741648e+02  9.558593e+09    2.868473    0.778239
# min      1.000000  2.015010e+08  2.116151e+10    0.000000    5.560000
# 25%    100.000000  2.015011e+08  2.116151e+11    0.000000    6.470000
# 50%    199.000000  2.015012e+08  2.116151e+11    1.000000    7.050000
# 75%    298.000000  2.015030e+08  2.116152e+11    3.000000    7.750000
# max    397.000000  2.015031e+08  2.116152e+11   13.000000    8.710000

# %%
skills_clean = skills.copy()
cgpa_clean = cgpa.copy()

# %%
skills_clean.drop('Unnamed: 4', axis=1, inplace = True )

# %%
skills_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 35 columns):
# S.No                                           281 non-null float64
# COLLEGE ROLL NUMBER                            281 non-null float64
# UNIVERSITY REGISTRATION NUMBER                 282 non-null float64
# NAME                                           282 non-null object
# DEGREE                                         282 non-null object
# BRANCH                                         282 non-null object
# GENDER                                         282 non-null object
# DATE OF BIRTH (DD/MM/YYYY)                     282 non-null object
# SSLC %                                         282 non-null float64
# HSC %                                          282 non-null float64
# DIPLOMA PERCENTAGE                             0 non-null float64
# COLLEGE EMAIL ID                               282 non-null object
# ...
